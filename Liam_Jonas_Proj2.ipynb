# %%
#book keeping
import pandas as pd
from pandas import DataFrame, read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# read in cvs, obtained from kaggle    https://www.kaggle.com/edumucelli/spotifys-worldwide-daily-song-ranking
Location = r'data.csv'
df = pd.read_csv(Location)
#raw data
df
# Out:
#          Position                                  Track Name  \
# 0               1                  Reggaetón Lento (Bailemos)
# 1               2                                    Chantaje
# 2               3                   Otra Vez (feat. J Balvin)
# 3               4                                Vente Pa' Ca
# 4               5                                      Safari
# 5               6                                La Bicicleta
# 6               7                                  Ay Mi Dios
# 7               8                          Andas En Mi Cabeza
# 8               9                                 Traicionera
# 9              10                                 Shaky Shaky
# 10             11                                  Vacaciones
# 11             12                      Dile Que Tu Me Quieres
# 12             13                             Let Me Love You
# 13             14                            DUELE EL CORAZON
# ...

# %%
#data has column track, this seperates it by song [rap]
plt.style.use('seaborn')

spot1=df.loc[df['Region'].isin(["us"])]

spot1 = spot1.loc[df['Track Name'].isin(['Bad and Boujee (feat. Lil Uzi Vert)'])]


spot2=df.loc[df['Region'].isin(["us"])]
spot2 = spot2.loc[df['Track Name'].isin(['Bounce Back'])]


spot3=df.loc[df['Region'].isin(["us"])]
spot3= spot3.loc[df['Track Name'].isin(['No Problem (feat. Lil Wayne & 2 Chainz)'])]


spot4=df.loc[df['Region'].isin(["us"])]
spot4 = spot4.loc[df['Track Name'].isin(['Black Beatles'])]#

# %%
#data has column track, this seperates it by song  [pop]

plt.style.use('seaborn')
pd.set_option('display.max_rows', 200)

spot9=df.loc[df['Region'].isin(["us"])]
spot9 = spot9.loc[df['Track Name'].isin(['Work from Home'])]

spot10=df.loc[df['Region'].isin(["us"])]
spot10 = spot10.loc[df['Track Name'].isin(['Into You'])]


spot11=df.loc[df['Region'].isin(["us"])]
spot11= spot11.loc[df['Track Name'].isin(['All Night'])]


spot12=df.loc[df['Region'].isin(["us"])]
spot12 = spot12.loc[df['Track Name'].isin(['Side To Side'])]
#wrnagled data
spot12
# Out:
#         Position    Track Name         Artist  Streams  \
# 771646        25  Side To Side  Ariana Grande   440123
# 771845        24  Side To Side  Ariana Grande   402640
# 772045        24  Side To Side  Ariana Grande   449632
# 772244        23  Side To Side  Ariana Grande   469393
# 772445        24  Side To Side  Ariana Grande   460724
# 772646        25  Side To Side  Ariana Grande   476302
# 772845        24  Side To Side  Ariana Grande   435370
# 773045        24  Side To Side  Ariana Grande   405319
# 773247        26  Side To Side  Ariana Grande   420588
# 773447        26  Side To Side  Ariana Grande   444598
# 773649        28  Side To Side  Ariana Grande   449411
# 773849        28  Side To Side  Ariana Grande   448080
# 774051        30  Side To Side  Ariana Grande   479560
# 774250        29  Side To Side  Ariana Grande   448414
# 774452        31  Side To Side  Ariana Grande   400860
# 774654        33  Side To Side  Ariana Grande   420762
# ...

# %%
#data has column track, this seperates it by song  [rock?]
plt.style.use('seaborn')
pd.set_option('display.max_rows', 200)

spot13=df.loc[df['Region'].isin(["us"])]
spot13 = spot13.loc[df['Track Name'].isin(['Believer'])]

spot14=df.loc[df['Region'].isin(["us"])]
spot14 = spot14.loc[df['Track Name'].isin(['Feel It Still'])]


spot15=df.loc[df['Region'].isin(["us"])]
spot15= spot15.loc[df['Track Name'].isin(['Thunder'])]


spot16=df.loc[df['Region'].isin(["us"])]
spot16 = spot16.loc[df['Track Name'].isin(['Ride'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-01-01'])]
spot99
# Out:
#         Position                                         Track Name  \
# 771622         1                Bad and Boujee (feat. Lil Uzi Vert)
# 771623         2                                          Fake Love
# 771624         3                                            Starboy
# 771625         4                                             Closer
# 771626         5                                      Black Beatles
# 771627         6                        Broccoli (feat. Lil Yachty)
# 771628         7                                          One Dance
# 771629         8                                           Caroline
# 771630         9                                    Let Me Love You
# 771631        10                                        Bounce Back
# 771632        11                                   I Feel It Coming
# 771633        12                                          24K Magic
# 771634        13                   Bad Things (with Camila Cabello)
# ...

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-02-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-03-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-04-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-05-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-06-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-07-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-08-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-09-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-10-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-11-01'])]

# %%
# used this to find the top song at the beginning of the month 
pd.set_option('display.max_rows', 200)
spot99=df.loc[df['Region'].isin(["us"])]
spot99 = spot99.loc[df['Date'].isin(['2017-12-01'])]

# %%
#4 subplots by genre, show chart postion over the year
plt.style.use('fivethirtyeight')

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(12,12))


spot1.plot(x='Date', y='Position', legend=True, ax=ax1,color='red',lw = 1.5)
ax1.set_title("Bad and Boujee (feat. Lil Uzi Vert)")
ax1.invert_yaxis()

spot2.plot(x='Date', y='Position', legend=False, ax=ax2,color='red',lw = 1.5)
ax2.set_title("Bounce Back")

spot3.plot(x='Date', y='Position', legend=False, ax=ax3,color='red',lw = 1.5)
ax3.set_title("No Problem (feat. Lil Wayne & 2 Chainz)")

spot4.plot(x='Date', y='Position', legend=False, ax=ax4,color='red',lw = 1.5)
ax4.set_title("Black Beatles")
# Out:
# Text(0.5,1,'Black Beatles')

# %%
#pop songs subplot 
plt.style.use('fivethirtyeight')
palette = plt.get_cmap('Set2')
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(12,12))


spot9.plot(x='Date', y='Position', legend=True, ax=ax1,color='purple',lw = 2.3)
ax1.set_title("Work from Home")
ax1.invert_yaxis()

spot10.plot(x='Date', y='Position', legend=False, ax=ax2,color='purple',lw = 2.3)
ax2.set_title("Into You")

spot11.plot(x='Date', y='Position', legend=False, ax=ax3,color='purple',lw = 2.3)
ax3.set_title("Treat You Better")

spot12.plot(x='Date', y='Position', legend=False, ax=ax4,color='purple',lw = 2.3)
ax4.set_title("Side to Side")
# Out:
# Text(0.5,1,'Side to Side')

# %%
# rock songs subplot 
plt.style.use('fivethirtyeight')
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(12,12))


spot13.plot(x='Date', y='Position', legend=True, ax=ax1,color='blue',lw = 2.3)
ax1.set_title("Believer")
ax1.invert_yaxis()

spot14.plot(x='Date', y='Position', legend=False,ax=ax2,color='blue',lw = 2.3) #
ax2.set_title("Feel It Still")

spot15.plot(x='Date', y='Position', legend=False, ax=ax3,color='blue',lw = 2.3)
ax3.set_title("Thunder")

spot16.plot(x='Date', y='Position', legend=False, ax=ax4,color='blue',lw = 2.3)
ax4.set_title("Ride")
# Out:
# Text(0.5,1,'Ride')

# %%
# more wrangling 
# maps the difference of position on the chart day by day for each song
pos1 = pd.DataFrame()
pos1['Bad and Boujee']=spot1['Position'].diff()
pos1= pos1.drop(pos1.index[0])
pos1['Bad and Boujee'] *= -1

pos2 = pd.DataFrame()
pos2['Bounce Back']=spot2['Position'].diff()
pos2= pos2.drop(pos2.index[0])
pos2['Bounce Back'] *= -1

pos3 = pd.DataFrame()
pos3['No Problem']=spot3['Position'].diff()
pos3= pos3.drop(pos3.index[0])
pos3['No Problem'] *= -1

pos4 = pd.DataFrame()
pos4['Black Beatles']=spot4['Position'].diff()
pos4= pos4.drop(pos4.index[0])
pos4['Black Beatles'] *= -1

pos9 = pd.DataFrame()
pos9['Work from Home']=spot9['Position'].diff()
pos9= pos9.drop(pos9.index[0])
pos9['Work from Home'] *= -1

pos10 = pd.DataFrame()
pos10['Into You']=spot10['Position'].diff()
pos10= pos10.drop(pos10.index[0])
pos10['Into You'] *= -1


pos11 = pd.DataFrame()
pos11['Treat You Better']=spot11['Position'].diff()
pos11= pos11.drop(pos11.index[0])
pos11['Treat You Better'] *= -1

pos12 = pd.DataFrame()
pos12['Side to Side']=spot12['Position'].diff()
pos12= pos12.drop(pos12.index[0])
pos12['Side to Side'] *= -1

pos13 = pd.DataFrame()
pos13['Ride']=spot13['Position'].diff()
pos13= pos13.drop(pos13.index[0])
pos13['Ride'] *= -1

pos14 = pd.DataFrame()
pos14['Feel It Still']=spot14['Position'].diff()
pos14= pos14.drop(pos14.index[0])
pos14['Feel It Still'] *= -1

pos15 = pd.DataFrame()
pos15['Thunder']=spot15['Position'].diff()
pos15= pos15.drop(pos15.index[0])
pos15['Thunder'] *= -1

pos16 = pd.DataFrame()
pos16['Believer']=spot16['Position'].diff()
pos16= pos16.drop(pos16.index[0])
pos16['Believer'] *= -1
pos17 = pd.DataFrame()



pos1 = pd.concat([pos1,pos2,pos3,pos4], axis=1, ignore_index=False)
pos9 = pd.concat([pos9,pos10,pos11,pos12], axis=1, ignore_index=False)
pos17 = pd.concat([pos13,pos14,pos15,pos16], axis=1, ignore_index=False)

# %%
# I tried a lot of different box plots, your's on github were the best tho
# shows distibution of differences on chart

#df = pd.DataFrame(data=d)
#print (pd.concat([pos1, pos2], sort=False))
#pos1['Bounce Back'] = pos2['Bounce Back'].map(pos1.set_index('Bad and Boujee'))
#pos1 =pos1.append(pos11, ignore_index=True)
#dr =dr.drop(dr.columns[[0]], axis=0)

#e = {'Bad and Boujee':[dr.columns[[0]]],'Bounce Back':[dr],'No Problem':[dr],'Black Beatles':[dr],'Work from Home':[dr],'Into You':[dr],'Treat You Better':[dr],'Side to Side':[dr],'Ride':[dr],'Pumped Up Kicks':[dr], 'Thunder':[dr],'Believer':[dr]}
#df = pd.DataFrame(data=e)
#df
#show boxplot of position
# change outlier point symbols


# 6 subplots to show streams on y axis x for date
plt.style.use('fivethirtyeight')
sns.set(style="darkgrid")
#g = sns.FacetGrid(pos1, col="Bad and Boujee")
#fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=True, figsize=(20,20))
#sns.FacetGrid(pos1, col_wrap=5, height=2)

#zoom in on boxplots

#pos1.boxplot( column = ['Bad and Boujee', 'Bounce Back','No Problem', 'Black Beatles'],ax=ax1)
#ax1.set_title("Hip-Hop")

#pos9.boxplot( column = ['Work from Home', 'Into You','Treat You Better', 'Side to Side'],ax=ax2)
#ax2.set_title("Pop")

#pos17.boxplot( column = ['Ride', 'Feel It Still','Thunder', 'Believer'],ax=ax3)
#ax3.set_title("Rock?")
#sns.stripplot(x=pos1["Bad and Boujee"],orient ="v",color = 'r',width =.3,linewidth =2.0,jitter=0.2, size=2.5)
#sns.boxplot(x=pos1["Bounce Back"],orient ="v",color = 'r',width =.3,linewidth =2.0)

#correction: adding jitter
ax = sns.boxplot( data=pos1)
ax = sns.stripplot( data=pos1, color="red", jitter=0.3, size=3)
plt.title("Hip-Hop Chart Change", loc="center",size= 15)
#plt.plot(a,color= 'r')
#plot.set_title("Bad and Boujee (feat. Lil Uzi Vert)")
#pos1
#boxplot = df.boxplot(by='X')
#da
#plt.set_title('change outlier\npoint symbols')


#plt.show()

#dr
#dr.shape[1]
#pos1
# Out:
# Text(0.5,1,'Hip-Hop Chart Change')

# %%
# pop
plt.style.use('fivethirtyeight')
sns.set(style="darkgrid")
palette = plt.get_cmap('Set2')
ax = sns.boxplot( data=pos9)
ax = sns.stripplot( data=pos9, color='purple', jitter=0.3, size=3)
plt.title("Pop Chart Change", loc="center",size= 15)
# Out:
# Text(0.5,1,'Pop Chart Change')

# %%
#rock
plt.style.use('fivethirtyeight')
sns.set(style="darkgrid")
ax = sns.boxplot( data=pos17)
ax = sns.stripplot( data=pos17, color='blue', alpha=.7,jitter=0.3, size=3)
plt.title("Rock Chart Change", loc="center",size= 15)
# Out:
# Text(0.5,1,'Rock Chart Change')

# %%
#make table of top 15 results
HHTOP15 = pd.DataFrame()
HHTOP15['Month'] = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
HHTOP15['# in Top 15']= [9,8,6,9,10,9,9,8,10,11,12,10]
HHTOP15
# Out:
#    Month  # in Top 15
# 0    Jan            9
# 1    Feb            8
# 2    Mar            6
# 3    Apr            9
# 4    May           10
# 5    Jun            9
# 6    Jul            9
# 7    Aug            8
# 8    Sep           10
# 9    Oct           11
# 10   Nov           12
# 11   Dec           10

# %%
# simple graph for top 15
plt.style.use('fivethirtyeight')
HHTOP15.plot(x='Month', y='# in Top 15', legend=True,color='red',lw = 2.3,title = 'How many Hip-Hop song in the top 15 per month')
